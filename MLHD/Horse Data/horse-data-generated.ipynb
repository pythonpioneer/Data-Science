# %% [markdown]
# <ul style="list-style-type:square;">
# <li>Create a dataset</li>
# <li>write the data into some csv file</li>
# </ul>

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as mp
import random
global _total
_total = 100000

# %%
# now create the list of horse gender
horse_gender = []

for _ in range(_total):
    i = random.randrange(-5, 100)
    if i < 0:
        horse_gender.append(np.NaN)
    elif i % 2 == 0:
        horse_gender.append('M')
    else: horse_gender.append('F')
len(horse_gender)
# Out:
# 100000

# %%
# crete the list of racer-horse
racer_horse = []

for _ in range(_total):
    i = random.randrange(-1, 100)
    if i < 0:
        racer_horse.append(np.NaN)
    elif i%2 == 0:
        racer_horse.append('Yes')
    else:
        racer_horse.append('No')
len(racer_horse)
# Out:
# 100000

# %%
''' The data is collected from a website "horse and country"
that states, horse height does not much depends on their gender,
it is mostly depends on their their breed like 
Shetland-pony height = 28 to 42 inches,
whehter other breeds are bigger than this and 
they belongs in range of 55 to 65 and 65 to 72 inches max. 
website link: https://horseandcountry.tv/horse-height-and-weight-guide/
'''
# Out:
# ' The data is collected from a website "horse and country"\nthat states, horse height does not much depends on their gender,\nit is mostly depends on their their breed like \nShetland-pony height = 28 to 42 inches,\nwhehter other breeds are bigger than this and \nthey belongs in range of 55 to 65 and 65 to 72 inches max. \nwebsite link: https://horseandcountry.tv/horse-height-and-weight-guide/\n'

# %%
'''The data is collected from a website "horse and country"
that states horse weight does not depend on their gender, like height 
it also depends on the breed of horse. and that varies from
horses like pony weight in range of 180 to 300
and others 300 to 500, 500 to 900 and 900 to 1200 max in kgs.
shire horses weight varies from 700 to 1200 so mostly we try to avoid 
weight over 1000 kg.'''
# Out:
# 'The data is collected from a website "horse and country"\nthat states horse weight does not depend on their gender, like height \nit also depends on the breed of horse. and that varies from\nhorses like pony weight in range of 180 to 300\nand others 300 to 500, 500 to 900 and 900 to 1200 max in kgs.\nshire horses weight varies from 700 to 1200 so mostly we try to avoid \nweight over 1000 kg.'

# %%
''' Generalizing horse height and weight
28-42 : 180-300
    28-32 : 180-220
    33-38 : 220-260
    39-42 : 260-300
    
43-55 : 300-500
    43-45 : 300-350
    46-49 : 350-400
    50-52 : 400-450
    53-55 : 450-500
    
56-65 : 500-900
    56-57 : 500-600
    58-60 : 600-700
    61-63 : 700-800
    64-65 : 800-900
    
66-72 : 900-1200
    66-67 : 900-960
    68-69 : 960-1080
    70-71 : 1080-1160
    71-72 : 1160-1200
'''
# Out:
# ' Generalizing horse height and weight\n28-42 : 180-300\n    28-32 : 180-220\n    33-38 : 220-260\n    39-42 : 260-300\n    \n43-55 : 300-500\n    43-45 : 300-350\n    46-49 : 350-400\n    50-52 : 400-450\n    53-55 : 450-500\n    \n56-65 : 500-900\n    56-57 : 500-600\n    58-60 : 600-700\n    61-63 : 700-800\n    64-65 : 800-900\n    \n66-72 : 900-1200\n    66-67 : 900-960\n    68-69 : 960-1080\n    70-71 : 1080-1160\n    71-72 : 1160-1200\n'

# %%
horse_height = []  # inches
horse_weight = []  # kgs

for _ in range(_total):
    i = random.randint(0, 10)
    
    # height : weight :: 28-42 : 180-300
    if i == 0:
        hh = random.randint(28, 42)
        if 28 <= hh <= 32:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(180, 220))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(180, 220))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
            
        elif 33 <= hh <= 38:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(220, 260))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(220, 260))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
            
        elif 39 <= hh <= 42:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(260, 300))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(260, 300))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
    #################################################################
       
    # height : weight :: 43-55 : 300-500
    elif 1 <= i <= 3:
        hh = random.randint(43, 55)
        if 43 <= hh <= 45:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(300, 350))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(300, 350))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        elif 46 <= hh <= 49:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(350, 400))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(350, 400))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        elif 50 <= hh <= 52:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(400, 450))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(400, 450))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        else:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(450, 500))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(450, 500))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
    ##################################################################
        
    # height : weight :: 56-65 : 500-900
    elif 4 <= i <= 9:
        hh = random.randint(56, 65)
        if 56 <= hh <= 57:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(500, 600))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(500, 600))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        elif 58 <= hh <= 60:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(600, 700))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(600, 700))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        elif 61 <= hh <= 63:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(700, 800))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(700, 800))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        else:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(800, 900))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(800, 900))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
            
    #####################################################################  
    
    # height : weight :: 56-65 : 500-900
    else:
        hh = random.randint(66, 72)
        if 66 <= hh <= 67:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(900, 960))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(900, 960))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        elif 68 <= hh <= 69:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(960, 1080))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(960, 1080))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        elif 70 <= hh <= 71:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(1080, 1160))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(1080, 1160))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
        
        else:
            temp = random.randint(0, 10)
            if temp >= 6:
                horse_height.append(hh)
                horse_weight.append(random.randint(1160, 1200))
            elif temp <= 1:
                horse_height.append(np.NaN)
                horse_weight.append(np.NaN)
            elif temp % 2 == 0:
                horse_height.append(np.NaN)
                horse_weight.append(random.randint(1160, 1200))
            else:
                horse_height.append(hh)
                horse_weight.append(np.NaN)
            
    #####################################################################    
print(len(horse_height))
len(horse_weight)
# Out:
# 100000
# 100000

# %%
# Creating a data frame 
horse_details = {
    'Serial no.': [i+1 for i in range(_total)],
    'Horse id': ['H'+str(i+1) for i in range(_total)],
    'Horse-Gender': horse_gender,
    'Horse-Height': horse_height,
    'Horse-Weight': horse_weight,
    'Racer-Horse': racer_horse 
}

horse_df = pd.DataFrame(horse_details)
horse_df.head(50)
# Out:
#     Serial no. Horse id Horse-Gender  Horse-Height  Horse-Weight Racer-Horse
# 0            1       H1            M           NaN           NaN         Yes
# 1            2       H2            F          56.0         522.0          No
# 2            3       H3            M          55.0           NaN          No
# 3            4       H4            M           NaN         686.0         Yes
# 4            5       H5            M           NaN           NaN         Yes
# 5            6       H6            F           NaN         414.0          No
# 6            7       H7            F          68.0         975.0         Yes
# 7            8       H8            M          64.0           NaN          No
# 8            9       H9            M           NaN           NaN         Yes
# 9           10      H10            M          65.0         862.0         Yes
# 10          11      H11            F           NaN         180.0          No
# 11          12      H12            F          66.0           NaN         Yes
# 12          13      H13            F           NaN         374.0         Yes
# 13          14      H14            F           NaN         211.0          No
# 14          15      H15            F          57.0         514.0          No
# 15          16      H16            M           NaN         735.0          No
# 16          17      H17            M           NaN         407.0          No
# 17          18      H18          NaN           NaN           NaN         Yes
# 18          19      H19          NaN          58.0         620.0         Yes
# 19          20      H20            F          29.0         211.0         Yes
# 20          21      H21            F          63.0         705.0          No
# 21          22      H22            M           NaN           NaN         Yes
# 22          23      H23            M          44.0         320.0          No
# 23          24      H24            F          69.0           NaN          No
# 24          25      H25            F          60.0         685.0          No
# 25          26      H26            M           NaN           NaN         Yes
# 26          27      H27            F          72.0        1167.0          No
# 27          28      H28            F          60.0           NaN         NaN
# 28          29      H29            M          58.0         665.0         Yes
# 29          30      H30            F          67.0         941.0         Yes
# 30          31      H31            F          56.0         537.0         Yes
# 31          32      H32            M          61.0         722.0          No
# 32          33      H33            F          50.0           NaN          No
# 33          34      H34            F          60.0         620.0         Yes
# 34          35      H35            M           NaN         632.0         Yes
# 35          36      H36            F           NaN           NaN          No
# 36          37      H37            F           NaN           NaN          No
# 37          38      H38            F          64.0         880.0          No
# 38          39      H39            F          55.0         487.0         Yes
# 39          40      H40            F          56.0           NaN          No
# 40          41      H41            M          59.0           NaN          No
# 41          42      H42          NaN           NaN         304.0         Yes
# 42          43      H43            F          56.0         584.0         Yes
# 43          44      H44            F           NaN           NaN         Yes
# 44          45      H45            F          64.0         843.0         Yes
# 45          46      H46            F           NaN           NaN         Yes
# 46          47      H47            M           NaN         457.0          No
# 47          48      H48            M           NaN         752.0          No
# 48          49      H49            F          65.0         883.0          No
# 49          50      H50            M           NaN         822.0         Yes

# %%
# now write this data to a CSV file
horse_df.to_csv('horse-details.csv', index=False)
